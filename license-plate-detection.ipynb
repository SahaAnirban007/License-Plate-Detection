# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 19.3 MB/s eta 0:00:0000:01
# ...

# %%
from ultralytics import YOLO
model = YOLO("yolo11s.yaml").load("yolo11s.pt")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 18.4M/18.4M [00:00<00:00, 161MB/s]
# Transferred 499/499 items from pretrained weights

# %%
# !yolo task=detect mode=train data="/kaggle/input/license/data.yaml" epochs=100 batch=8 imgsz=640 patience=10
# Out:
# Ultralytics 8.3.146 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect mode=predict source="/kaggle/input/license/test/images" model="/kaggle/working/runs/detect/train/weights/best.pt" save=true
# Out:
# Ultralytics 8.3.146 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,586,637 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/395 /kaggle/input/license/test/images/00c2cca1-854e-465b-88c9-035e56207a76_jpg.rf.23ca66a8fe2cb8dc60e3f61d300781cd.jpg: 448x640 3 LicensePlates, 45.1ms
# image 2/395 /kaggle/input/license/test/images/022fa55d-7c2d-45a4-8f9d-9e8e726f6d21_jpg.rf.681bf3507050941bc0189fd50fcf283e.jpg: 448x640 3 LicensePlates, 8.9ms
# image 3/395 /kaggle/input/license/test/images/03o6p96xjmka1_jpg.rf.7d9d98a93a02cf3e7ef0684a03e50caa.jpg: 448x640 1 LicensePlate, 8.5ms
# image 4/395 /kaggle/input/license/test/images/04916a30e99034bb2_jpg.rf.d907fdc3c9be74f49986714b8f72509f.jpg: 448x640 1 LicensePlate, 8.6ms
# image 5/395 /kaggle/input/license/test/images/04b2c656-91ad-4e0e-8530-10faef7a2031_jpg.rf.8dfa458ce2ec7d859f6003f05dd6183e.jpg: 448x640 2 LicensePlates, 8.3ms
# ...

# %%
# !yolo segment predict model="/kaggle/working/runs/detect/train/weights/best.pt" source='/kaggle/input/license/test/images' save=true
# Out:
# WARNING ⚠️ conflicting 'task=segment' passed with 'task=detect' model. Ignoring 'task=segment' and updating to 'task=detect' to match model.
# Ultralytics 8.3.146 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,586,637 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/395 /kaggle/input/license/test/images/00c2cca1-854e-465b-88c9-035e56207a76_jpg.rf.23ca66a8fe2cb8dc60e3f61d300781cd.jpg: 448x640 3 LicensePlates, 46.7ms
# image 2/395 /kaggle/input/license/test/images/022fa55d-7c2d-45a4-8f9d-9e8e726f6d21_jpg.rf.681bf3507050941bc0189fd50fcf283e.jpg: 448x640 3 LicensePlates, 9.3ms
# image 3/395 /kaggle/input/license/test/images/03o6p96xjmka1_jpg.rf.7d9d98a93a02cf3e7ef0684a03e50caa.jpg: 448x640 1 LicensePlate, 8.1ms
# image 4/395 /kaggle/input/license/test/images/04916a30e99034bb2_jpg.rf.d907fdc3c9be74f49986714b8f72509f.jpg: 448x640 1 LicensePlate, 7.9ms
# ...
